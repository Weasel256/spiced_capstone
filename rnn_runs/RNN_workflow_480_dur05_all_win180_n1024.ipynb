# %% [markdown]
# ## Pre-Processing

# %%
import os
os.chdir('..')

from source import data_import
from source.constants import CHANNELS, DEFAULT_PATIENTS
import numpy as np
import matplotlib.pyplot as plt

import pandas as pd
# os.environ["MODIN_ENGINE"] = "ray"
# import modin.pandas as pd
# import ray
# ray.shutdown()
# ray.init()

from source.filter_eeg_channels import filter_eeg_channels
from source.calculate_mean_psd import calculate_mean_psd
from source.constants import CHANNELS, FREQUENCY_RANGES
from source.data_import import save_file, load_file 
                                            
from sklearn.preprocessing import StandardScaler, minmax_scale, MinMaxScaler

# %%
## PARAMETERS ##
SKIP_DATA = True
data_filename = None #"preprocessed_240_dur05_all.arrow" # data will be loaded/saved with this filename. Put None to skip saving the file

SKIP_FEATURES = True
feature_filename = 'features_240_dur05_all.npy' # data will be loaded/saved with this filename. Put None to skip saving the file

### DATA ###
# Load Patient Data #
patient_ids = None #DEFAULT_PATIENTS #DEFAULT_PATIENTS # use DEFAULT_PATIENTS for default patients selection
nr_segments=480
segment_duration=0.5
ictal_segmentation_foo=data_import.preictal_segmentation
interictal_segmentation_foo=data_import.inter_segmentation
channels=CHANNELS
seizure_offset=0

# filter #
exclude_ranges=[[58, 62], [118, 122]]

### FEATURES ###
target_colname = 'target'
PRED_INTERVAL = 6000 # how long should a segment count as preictal in seconds

window_size = 180 # Define the sequence_train window size

# %%
if not SKIP_DATA:
    # Load Patient Data
    p_df = data_import.load_segmented_data(patient_ids=patient_ids,
                                            nr_segments=nr_segments,
                                            segment_duration=segment_duration,
                                            ictal_segmentation_foo=data_import.preictal_segmentation,
                                            interictal_segmentation_foo=data_import.inter_segmentation,
                                            channels=channels,
                                            seizure_offset=seizure_offset
                                            )
    
    # Filter
    fit_df = filter_eeg_channels(p_df, CHANNELS, fs=256, exclude_ranges=exclude_ranges, Q=30)
    pd_toconcat = p_df[['epoch', 'segment_id']]
    fit_df = pd.concat(objs=[fit_df, pd_toconcat], axis =1)
    save_file(data=fit_df, file_name=data_filename)
    fit_df.head()
elif data_filename is not None:
    fit_df = load_file(data_filename)
    fit_df = pd.DataFrame(fit_df)
    fit_df.head()

# %% [markdown]
# ## Feature Extraction

# %%
### aggregate Functions for mean psd:
delta = lambda x: calculate_mean_psd(x, nperseg=128, noverlap=64, frequency_ranges={'Delta' : FREQUENCY_RANGES['Delta']})[x.name]['Delta']
theta = lambda x: calculate_mean_psd(x, nperseg=128, noverlap=64, frequency_ranges={'Theta' : FREQUENCY_RANGES['Theta']})[x.name]['Theta']
gamma = lambda x: calculate_mean_psd(x, nperseg=128, noverlap=64, frequency_ranges={'Gamma': FREQUENCY_RANGES['Gamma']})[x.name]['Gamma']

delta_agg = pd.NamedAgg(column='delta', aggfunc=delta)
theta_agg = pd.NamedAgg(column='theta', aggfunc=theta)
gamma_agg = pd.NamedAgg(column='gamma', aggfunc=gamma)

### aggregate mean features:
abs_mean = lambda x: x.apply(abs).mean()
abs_mean_agg = pd.NamedAgg(column='abs_mean', aggfunc=abs_mean)

### aggregate Functions for target:
target_foo = lambda x, pred_interval=PRED_INTERVAL: 0 < x.dt.total_seconds().min() < pred_interval

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

def preprocess_data(df, window_size):
    # Grouping and aggregating features
    df_features = df.groupby(['epoch', 'segment_id']).agg(
        {C: ['std', 'var', abs_mean_agg, delta_agg, theta_agg, gamma_agg] for C in CHANNELS} | 
        {target_colname: [target_foo]}
    )
    
    # Renaming columns
    df_features.columns = ['_'.join(col).strip() for col in df_features.columns.values if target_colname != col[0]] + [target_colname]
    df_features.reset_index(inplace=True)


    # Reshaping array
    original_array = np.array(df_features)
    epoch_column = original_array[:, 0]
    num_epochs = df_features.epoch.unique()[-1]
    num_segments = len(df_features.segment_id.unique())
    reshaped_array = np.empty((num_epochs, num_segments, original_array.shape[1]))

    for epoch in range(num_epochs):
        start_idx = epoch * num_segments
        end_idx = (epoch + 1) * num_segments
        reshaped_array[epoch, :, :] = original_array[start_idx:end_idx, :]

    # Creating sequence trains
    num_batches, num_sequences, num_features = reshaped_array.shape
    num_augmented_batches = num_sequences - window_size + 1

    data = np.zeros((num_batches * num_augmented_batches, window_size, num_features))

    for batch_idx in range(num_batches):
        for seq_idx in range(num_augmented_batches):
            data[batch_idx * num_augmented_batches + seq_idx, :, :] = reshaped_array[batch_idx, seq_idx:seq_idx + window_size, :]
        
    return data

# %%
if not SKIP_FEATURES:
    data = preprocess_data(fit_df, window_size=window_size)
    print(data.shape)
    save_file(data=data, file_name=feature_filename)
else:
    data = load_file(feature_filename)
# Out:
# loading npy

# %%
# %run model_rnn.ipynb
# Out:
# WARNING:tensorflow:From d:\_c\spiced\ai-seizure-detectives\venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# data already loaded in parent notebook
# 544 of epochs for training, 136 of epochs for testing/validation
# train shape (163744, 180, 62) ratio of seizures 0.25
# test shape (40936, 180, 62), ratio of seizures 0.22
# train shape (163744, 180, 60)
# test shape (40936, 180, 60)
# WARNING:tensorflow:From d:\_c\spiced\ai-seizure-detectives\venv\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1024)              4444160
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense (Dense)               (None, 1024)              1049600
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  batch_normalization (Batch  (None, 1024)              4096
#  Normalization)
#
#  dense_1 (Dense)             (None, 1)                 1025
#
# =================================================================
# Total params: 5498881 (20.98 MB)
# Trainable params: 5496833 (20.97 MB)
# Non-trainable params: 2048 (8.00 KB)
# _________________________________________________________________
# Epoch 1/80
# WARNING:tensorflow:From d:\_c\spiced\ai-seizure-detectives\venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From d:\_c\spiced\ai-seizure-detectives\venv\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 17/17 [==============================] - 850s 46s/step - loss: 57.6179 - accuracy: 0.4288 - auc: 0.5081 - val_loss: 57.2453 - val_accuracy: 0.2229 - val_auc: 0.5814
# Epoch 2/80
# d:\_c\spiced\ai-seizure-detectives\venv\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 17/17 [==============================] - 778s 46s/step - loss: 57.0357 - accuracy: 0.4570 - auc: 0.5503 - val_loss: 56.7214 - val_accuracy: 0.2274 - val_auc: 0.6052
# Epoch 3/80
# 17/17 [==============================] - 791s 46s/step - loss: 56.4799 - accuracy: 0.4740 - auc: 0.5834 - val_loss: 56.1891 - val_accuracy: 0.2352 - val_auc: 0.6526
# Epoch 4/80
# 17/17 [==============================] - 767s 46s/step - loss: 55.9398 - accuracy: 0.4856 - auc: 0.6012 - val_loss: 55.6595 - val_accuracy: 0.2501 - val_auc: 0.6637
# Epoch 5/80
# 17/17 [==============================] - 728s 43s/step - loss: 55.4011 - accuracy: 0.4945 - auc: 0.6165 - val_loss: 55.1329 - val_accuracy: 0.2584 - val_auc: 0.6698
# Epoch 6/80
# 17/17 [==============================] - 759s 45s/step - loss: 54.8750 - accuracy: 0.5012 - auc: 0.6241 - val_loss: 54.6101 - val_accuracy: 0.2658 - val_auc: 0.6783
# Epoch 7/80
# 17/17 [==============================] - 786s 47s/step - loss: 54.3477 - accuracy: 0.5101 - auc: 0.6336 - val_loss: 54.0903 - val_accuracy: 0.2825 - val_auc: 0.6721
# Epoch 8/80
# 17/17 [==============================] - 792s 47s/step - loss: 53.8229 - accuracy: 0.5163 - auc: 0.6444 - val_loss: 53.5748 - val_accuracy: 0.2918 - val_auc: 0.6739
# Epoch 9/80
# 17/17 [==============================] - 769s 46s/step - loss: 53.3085 - accuracy: 0.5174 - auc: 0.6477 - val_loss: 53.0641 - val_accuracy: 0.3004 - val_auc: 0.6743
# Epoch 10/80
# 17/17 [==============================] - 787s 47s/step - loss: 52.7919 - accuracy: 0.5276 - auc: 0.6592 - val_loss: 52.5568 - val_accuracy: 0.3092 - val_auc: 0.6785
# Epoch 11/80
# 17/17 [==============================] - 760s 45s/step - loss: 52.2839 - accuracy: 0.5331 - auc: 0.6657 - val_loss: 52.0542 - val_accuracy: 0.3189 - val_auc: 0.6776
# Epoch 12/80
# 17/17 [==============================] - 747s 44s/step - loss: 51.7806 - accuracy: 0.5369 - auc: 0.6714 - val_loss: 51.5537 - val_accuracy: 0.3292 - val_auc: 0.6776
# Epoch 13/80
# 17/17 [==============================] - 786s 47s/step - loss: 51.2799 - accuracy: 0.5429 - auc: 0.6778 - val_loss: 51.0583 - val_accuracy: 0.3398 - val_auc: 0.6832
# Epoch 14/80
# 17/17 [==============================] - 770s 46s/step - loss: 50.7855 - accuracy: 0.5473 - auc: 0.6822 - val_loss: 50.5677 - val_accuracy: 0.3531 - val_auc: 0.6792
# Epoch 15/80
# 17/17 [==============================] - 750s 45s/step - loss: 50.2930 - accuracy: 0.5529 - auc: 0.6903 - val_loss: 50.0838 - val_accuracy: 0.3633 - val_auc: 0.6761
# Epoch 16/80
# 17/17 [==============================] - 822s 49s/step - loss: 49.8059 - accuracy: 0.5551 - auc: 0.6953 - val_loss: 49.5991 - val_accuracy: 0.3816 - val_auc: 0.6793
# Epoch 17/80
# 17/17 [==============================] - 744s 44s/step - loss: 49.3201 - accuracy: 0.5620 - auc: 0.7040 - val_loss: 49.1226 - val_accuracy: 0.3917 - val_auc: 0.6823
# Epoch 18/80
# 17/17 [==============================] - 785s 47s/step - loss: 48.8403 - accuracy: 0.5661 - auc: 0.7104 - val_loss: 48.6470 - val_accuracy: 0.4157 - val_auc: 0.6840
# Epoch 19/80
# 17/17 [==============================] - 756s 45s/step - loss: 48.3648 - accuracy: 0.5724 - auc: 0.7174 - val_loss: 48.1780 - val_accuracy: 0.4276 - val_auc: 0.6831
# Epoch 20/80
# 17/17 [==============================] - 798s 47s/step - loss: 47.8910 - accuracy: 0.5789 - auc: 0.7264 - val_loss: 47.7081 - val_accuracy: 0.4558 - val_auc: 0.6887
# Epoch 21/80
# 17/17 [==============================] - 751s 45s/step - loss: 47.4218 - accuracy: 0.5836 - auc: 0.7361 - val_loss: 47.2425 - val_accuracy: 0.4995 - val_auc: 0.6951
# Epoch 22/80
# 17/17 [==============================] - 761s 45s/step - loss: 46.9520 - accuracy: 0.5941 - auc: 0.7494 - val_loss: 46.7793 - val_accuracy: 0.5044 - val_auc: 0.6956
# Epoch 23/80
# 17/17 [==============================] - 883s 53s/step - loss: 46.4849 - accuracy: 0.6064 - auc: 0.7652 - val_loss: 46.3231 - val_accuracy: 0.5453 - val_auc: 0.7076
# Epoch 24/80
# 17/17 [==============================] - 757s 45s/step - loss: 46.0142 - accuracy: 0.6291 - auc: 0.7879 - val_loss: 45.8521 - val_accuracy: 0.6289 - val_auc: 0.7099
# Epoch 25/80
# 17/17 [==============================] - 780s 46s/step - loss: 45.5415 - accuracy: 0.6600 - auc: 0.8079 - val_loss: 45.4285 - val_accuracy: 0.6688 - val_auc: 0.7330
# Epoch 26/80
# 17/17 [==============================] - 732s 43s/step - loss: 45.0798 - accuracy: 0.6897 - auc: 0.8210 - val_loss: 45.0882 - val_accuracy: 0.6703 - val_auc: 0.7357
# Epoch 27/80
# 17/17 [==============================] - 761s 45s/step - loss: 44.6274 - accuracy: 0.7163 - auc: 0.8325 - val_loss: 44.6687 - val_accuracy: 0.6589 - val_auc: 0.7383
# Epoch 28/80
# 17/17 [==============================] - 752s 44s/step - loss: 44.1808 - accuracy: 0.7356 - auc: 0.8407 - val_loss: 44.3263 - val_accuracy: 0.6265 - val_auc: 0.7362
# Epoch 29/80
# 17/17 [==============================] - 768s 46s/step - loss: 43.7411 - accuracy: 0.7474 - auc: 0.8492 - val_loss: 43.9906 - val_accuracy: 0.6222 - val_auc: 0.7462
# Epoch 30/80
# 17/17 [==============================] - 753s 45s/step - loss: 43.3114 - accuracy: 0.7591 - auc: 0.8541 - val_loss: 43.6017 - val_accuracy: 0.6784 - val_auc: 0.7495
# Epoch 31/80
# 17/17 [==============================] - 786s 47s/step - loss: 42.8838 - accuracy: 0.7676 - auc: 0.8604 - val_loss: 43.2255 - val_accuracy: 0.6110 - val_auc: 0.7405
# Epoch 32/80
# 17/17 [==============================] - 755s 45s/step - loss: 42.4611 - accuracy: 0.7743 - auc: 0.8663 - val_loss: 42.8583 - val_accuracy: 0.6264 - val_auc: 0.7369
# Epoch 33/80
# 17/17 [==============================] - 745s 44s/step - loss: 42.0437 - accuracy: 0.7822 - auc: 0.8717 - val_loss: 42.5348 - val_accuracy: 0.6373 - val_auc: 0.7425
# Epoch 34/80
# 17/17 [==============================] - 766s 46s/step - loss: 41.6289 - accuracy: 0.7886 - auc: 0.8783 - val_loss: 42.0526 - val_accuracy: 0.6368 - val_auc: 0.7320
# Epoch 35/80
# 17/17 [==============================] - 794s 47s/step - loss: 41.2195 - accuracy: 0.7930 - auc: 0.8833 - val_loss: 41.7363 - val_accuracy: 0.6484 - val_auc: 0.7413
# Epoch 36/80
# 17/17 [==============================] - 753s 45s/step - loss: 40.8131 - accuracy: 0.8008 - auc: 0.8891 - val_loss: 41.3210 - val_accuracy: 0.6381 - val_auc: 0.7273
# Epoch 37/80
# 17/17 [==============================] - 774s 46s/step - loss: 40.4132 - accuracy: 0.8039 - auc: 0.8928 - val_loss: 40.9799 - val_accuracy: 0.6063 - val_auc: 0.7217
# Epoch 38/80
# 17/17 [==============================] - 732s 43s/step - loss: 40.0153 - accuracy: 0.8089 - auc: 0.8977 - val_loss: 40.5934 - val_accuracy: 0.6038 - val_auc: 0.7116
# Epoch 39/80
# 17/17 [==============================] - 760s 45s/step - loss: 39.6199 - accuracy: 0.8151 - auc: 0.9031 - val_loss: 40.3283 - val_accuracy: 0.6278 - val_auc: 0.7217
# Epoch 40/80
# 17/17 [==============================] - 748s 44s/step - loss: 39.2280 - accuracy: 0.8196 - auc: 0.9083 - val_loss: 40.0033 - val_accuracy: 0.6482 - val_auc: 0.7225
# Epoch 41/80
# 17/17 [==============================] - 740s 44s/step - loss: 38.8448 - accuracy: 0.8221 - auc: 0.9107 - val_loss: 39.6183 - val_accuracy: 0.6453 - val_auc: 0.7152
# Epoch 42/80
# 17/17 [==============================] - 778s 46s/step - loss: 38.4633 - accuracy: 0.8246 - auc: 0.9143 - val_loss: 39.3084 - val_accuracy: 0.6863 - val_auc: 0.7162
# Epoch 43/80
# 17/17 [==============================] - 741s 44s/step - loss: 38.0828 - accuracy: 0.8297 - auc: 0.9187 - val_loss: 38.9969 - val_accuracy: 0.6777 - val_auc: 0.7112
# Epoch 44/80
# 17/17 [==============================] - 791s 46s/step - loss: 37.7074 - accuracy: 0.8337 - auc: 0.9224 - val_loss: 38.5839 - val_accuracy: 0.6999 - val_auc: 0.7079
# Epoch 45/80
# 17/17 [==============================] - 740s 44s/step - loss: 37.3326 - accuracy: 0.8380 - auc: 0.9275 - val_loss: 38.2686 - val_accuracy: 0.7165 - val_auc: 0.7094
# Epoch 46/80
# 17/17 [==============================] - 754s 45s/step - loss: 36.9647 - accuracy: 0.8433 - auc: 0.9306 - val_loss: 37.9698 - val_accuracy: 0.6537 - val_auc: 0.6981
# Epoch 47/80
# 17/17 [==============================] - 844s 50s/step - loss: 36.6178 - accuracy: 0.8366 - auc: 0.9257 - val_loss: 37.6284 - val_accuracy: 0.7003 - val_auc: 0.7078
# Epoch 48/80
# 17/17 [==============================] - 795s 47s/step - loss: 36.2446 - accuracy: 0.8454 - auc: 0.9346 - val_loss: 37.2923 - val_accuracy: 0.6676 - val_auc: 0.6939
# Epoch 49/80
# 17/17 [==============================] - 772s 46s/step - loss: 35.8889 - accuracy: 0.8508 - auc: 0.9367 - val_loss: 36.9185 - val_accuracy: 0.6941 - val_auc: 0.6963
# Epoch 50/80
# 17/17 [==============================] - 763s 45s/step - loss: 35.5311 - accuracy: 0.8553 - auc: 0.9414 - val_loss: 36.6065 - val_accuracy: 0.6834 - val_auc: 0.6831
# Epoch 51/80
# 17/17 [==============================] - 750s 44s/step - loss: 35.1835 - accuracy: 0.8582 - auc: 0.9425 - val_loss: 36.2686 - val_accuracy: 0.7166 - val_auc: 0.6997
# Epoch 52/80
# 17/17 [==============================] - 791s 45s/step - loss: 34.8361 - accuracy: 0.8614 - auc: 0.9451 - val_loss: 36.0138 - val_accuracy: 0.6976 - val_auc: 0.6905
# Epoch 53/80
# 17/17 [==============================] - 755s 45s/step - loss: 34.4923 - accuracy: 0.8635 - auc: 0.9473 - val_loss: 35.6892 - val_accuracy: 0.6448 - val_auc: 0.6744
# Epoch 54/80
# 17/17 [==============================] - 750s 44s/step - loss: 34.1716 - accuracy: 0.8582 - auc: 0.9410 - val_loss: 35.2422 - val_accuracy: 0.6660 - val_auc: 0.6855
# Epoch 55/80
# 17/17 [==============================] - 815s 49s/step - loss: 33.8289 - accuracy: 0.8587 - auc: 0.9458 - val_loss: 35.0315 - val_accuracy: 0.6745 - val_auc: 0.6836
# Epoch 56/80
# 17/17 [==============================] - 757s 45s/step - loss: 33.4851 - accuracy: 0.8681 - auc: 0.9518 - val_loss: 34.7360 - val_accuracy: 0.7238 - val_auc: 0.6888
# Epoch 57/80
# 17/17 [==============================] - 771s 46s/step - loss: 33.1585 - accuracy: 0.8715 - auc: 0.9519 - val_loss: 34.3663 - val_accuracy: 0.7206 - val_auc: 0.6871
# Epoch 58/80
# 17/17 [==============================] - 768s 46s/step - loss: 32.8313 - accuracy: 0.8736 - auc: 0.9537 - val_loss: 34.1224 - val_accuracy: 0.7133 - val_auc: 0.6901
# Epoch 59/80
# 17/17 [==============================] - 782s 45s/step - loss: 32.5073 - accuracy: 0.8736 - auc: 0.9553 - val_loss: 33.8230 - val_accuracy: 0.7232 - val_auc: 0.6873
# Epoch 60/80
# 17/17 [==============================] - 755s 45s/step - loss: 32.1874 - accuracy: 0.8785 - auc: 0.9563 - val_loss: 33.5247 - val_accuracy: 0.6650 - val_auc: 0.6732
# Epoch 61/80
# 17/17 [==============================] - 757s 45s/step - loss: 31.8674 - accuracy: 0.8803 - auc: 0.9585 - val_loss: 33.2464 - val_accuracy: 0.7212 - val_auc: 0.6914
# Epoch 62/80
# 17/17 [==============================] - 748s 43s/step - loss: 31.5531 - accuracy: 0.8819 - auc: 0.9594 - val_loss: 32.8866 - val_accuracy: 0.7170 - val_auc: 0.6803
# Epoch 63/80
# 17/17 [==============================] - 754s 44s/step - loss: 31.2559 - accuracy: 0.8764 - auc: 0.9550 - val_loss: 32.5026 - val_accuracy: 0.6558 - val_auc: 0.6669
# Epoch 64/80
# 17/17 [==============================] - 729s 43s/step - loss: 30.9380 - accuracy: 0.8785 - auc: 0.9598 - val_loss: 32.4133 - val_accuracy: 0.7243 - val_auc: 0.6886
# Epoch 65/80
# 17/17 [==============================] - 753s 45s/step - loss: 30.6256 - accuracy: 0.8890 - auc: 0.9629 - val_loss: 32.0678 - val_accuracy: 0.7003 - val_auc: 0.6790
# Epoch 66/80
# 17/17 [==============================] - 746s 43s/step - loss: 30.3220 - accuracy: 0.8891 - auc: 0.9640 - val_loss: 31.7970 - val_accuracy: 0.7180 - val_auc: 0.6898
# Epoch 67/80
# 17/17 [==============================] - 763s 44s/step - loss: 30.0265 - accuracy: 0.8886 - auc: 0.9632 - val_loss: 31.5047 - val_accuracy: 0.6746 - val_auc: 0.6773
# Epoch 68/80
# 17/17 [==============================] - 893s 53s/step - loss: 29.7261 - accuracy: 0.8907 - auc: 0.9649 - val_loss: 31.3470 - val_accuracy: 0.7257 - val_auc: 0.6916
# Epoch 69/80
# 17/17 [==============================] - 1303s 77s/step - loss: 29.4381 - accuracy: 0.8910 - auc: 0.9634 - val_loss: 30.9424 - val_accuracy: 0.7096 - val_auc: 0.6827
# Epoch 70/80
# 17/17 [==============================] - 1317s 77s/step - loss: 29.1423 - accuracy: 0.8922 - auc: 0.9655 - val_loss: 30.6417 - val_accuracy: 0.7263 - val_auc: 0.6847
# Epoch 71/80
# 17/17 [==============================] - 1401s 78s/step - loss: 28.8487 - accuracy: 0.8957 - auc: 0.9677 - val_loss: 30.3602 - val_accuracy: 0.6969 - val_auc: 0.6781
# Epoch 72/80
# 17/17 [==============================] - 1344s 80s/step - loss: 28.5587 - accuracy: 0.8976 - auc: 0.9692 - val_loss: 30.0860 - val_accuracy: 0.7231 - val_auc: 0.6803
# Epoch 73/80
# 17/17 [==============================] - 1331s 79s/step - loss: 28.2758 - accuracy: 0.8990 - auc: 0.9694 - val_loss: 29.8074 - val_accuracy: 0.7294 - val_auc: 0.6901
# Epoch 74/80
# 17/17 [==============================] - 1278s 75s/step - loss: 28.0137 - accuracy: 0.8916 - auc: 0.9635 - val_loss: 29.6144 - val_accuracy: 0.7119 - val_auc: 0.6837
# Epoch 75/80
# 17/17 [==============================] - 789s 47s/step - loss: 27.7223 - accuracy: 0.8969 - auc: 0.9686 - val_loss: 29.2568 - val_accuracy: 0.7208 - val_auc: 0.6809
# Epoch 76/80
# 17/17 [==============================] - 811s 48s/step - loss: 27.4409 - accuracy: 0.9004 - auc: 0.9704 - val_loss: 28.9457 - val_accuracy: 0.7198 - val_auc: 0.6702
# Epoch 77/80
# 17/17 [==============================] - 745s 44s/step - loss: 27.1633 - accuracy: 0.9032 - auc: 0.9721 - val_loss: 28.7443 - val_accuracy: 0.7236 - val_auc: 0.6814
# Epoch 78/80
# 17/17 [==============================] - 771s 46s/step - loss: 26.8958 - accuracy: 0.9029 - auc: 0.9712 - val_loss: 28.4143 - val_accuracy: 0.6887 - val_auc: 0.6664
# Epoch 79/80
# 17/17 [==============================] - 800s 48s/step - loss: 26.6232 - accuracy: 0.9046 - auc: 0.9729 - val_loss: 28.2108 - val_accuracy: 0.7233 - val_auc: 0.6860
# Epoch 80/80
# 17/17 [==============================] - 792s 47s/step - loss: 26.3561 - accuracy: 0.9059 - auc: 0.9733 - val_loss: 27.9273 - val_accuracy: 0.6808 - val_auc: 0.6717
# 1280/1280 - 101s - loss: 27.9273 - accuracy: 0.6808 - auc: 0.6717 - 101s/epoch - 79ms/step
# Model accuracy: [27.92727279663086, 0.6807699799537659, 0.6716660261154175]
# 5117/5117 [==============================] - 400s 78ms/step
# 1280/1280 [==============================] - 102s 80ms/step
# 1280/1280 [==============================] - 104s 81ms/step - loss: 27.9273 - accuracy: 0.6808 - auc: 0.6717
# Loss: 27.92727279663086
# AUC: 0.6807699799537659
# Accuracy: 0.6716660261154175
# Precision: 0.3650581473065098
# Recall: 0.6048726467331118
# Metrics:  ['loss', 'accuracy', 'auc']
# Results:  [27.92727279663086, 0.6807699799537659, 0.6716660261154175]
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.70      0.77     31906
#          1.0       0.37      0.60      0.46      9030
#
#     accuracy                           0.68     40936
#    macro avg       0.61      0.65      0.61     40936
# weighted avg       0.75      0.68      0.70     40936
# Ein Unterverzeichnis oder eine Datei mit dem Namen "-p" existiert bereits.
# Folgender Fehler trat auf: -p.
# Ein Unterverzeichnis oder eine Datei mit dem Namen "saved_model" existiert bereits.
# Folgender Fehler trat auf: saved_model.
# INFO:tensorflow:Assets written to: saved_model/my_RNN_model_60per5_fixing_overfit\assets
# INFO:tensorflow:Assets written to: saved_model/my_RNN_model_60per5_fixing_overfit\assets
